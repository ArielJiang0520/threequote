# %%
from viewer import TweetCollection as TC
import pandas as pd
from nltk.tokenize import TreebankWordTokenizer

# %%
pd.set_option('display.max_colwidth', None)

# %%
data = TC('snapchat')
data.df
# Out:
#               UserName                  Timestamp  \
# 0     @snapchatsupport  2021-01-01 23:36:18+00:00
# 1     @snapchatsupport  2021-01-01 23:35:30+00:00
# 2     @xkombuchaqueenx  2021-01-01 22:00:18+00:00
# 3     @snapchatsupport  2021-01-01 20:55:30+00:00
# 4            @Bruhreeb  2021-01-01 20:53:47+00:00
# ...                ...                        ...
# 2368  @snapchatsupport  2021-03-03 01:51:55+00:00
# 2369  @snapchatsupport  2021-03-03 01:12:43+00:00
# 2370  @snapchatsupport  2021-03-03 00:59:02+00:00
# 2371     @Thegreat_tim  2021-03-03 00:56:04+00:00
# 2372        @AlClemist  2021-03-03 00:23:04+00:00
#
#                                                                                                                                                                                                                                                                                                                   Text  \
# ...

# %%
data = TC('instacart')
data.df
_, replies = data.reply_thread('@Instacart', verbose=True)
# Out:
#     2021-01-07 14:26:20+00:00 https://twitter.com/Instacart/status/1347187820331474951
#     @Instacart replied to @intothelavender's tweet:
#
# @intothelavender: @Instacart
#  hi there! In the “report an issue” menu you should add an option for wrong quantity. I ordered 2 of something and only got 1, so now it looks like I’m reporting I got 0 because there wasn’t another option. I’m not a liar I swear.
#
# @Instacart: Hi
#  there, thanks for reaching out! We are continuously making changes to improve and feedback like this helps a bunch
#  ! Please let me know if you need assistance creating this item issue in your account. We are here if you need us! -Gwen
#
#     Time Elapsed: 0 days 00:03:27
#
#
#
#     2021-01-20 13:57:12+00:00 https://twitter.com/Instacart/status/1351891529401565187
#     @Instacart replied to @kealundey's tweet:
#
# @kealundey: Well he found queso but he got me potato chips instead of tortilla chips.
#  Human error really is something else.
#
# ...

# %%
TC.search_by_exact_match(data.df, 'solved')
# Out:
#              UserName                  Timestamp  \
# 30        @yeahbettea  2021-01-05 18:03:29+00:00
# 32     @nope_its_lily  2021-01-05 16:45:04+00:00
# 50           @TMendes  2021-01-07 16:50:52+00:00
# 93        @CJCoolHerc  2021-01-14 17:12:33+00:00
# 123       @shamsingal  2021-01-19 12:39:14+00:00
# 125  @MyWordsYourEyes  2021-01-19 02:54:04+00:00
# 157          @RRitzyR  2021-01-22 21:03:50+00:00
# 189  @taralovesyoutoo  2021-01-23 21:35:43+00:00
# 202           @laa111  2021-01-25 21:55:14+00:00
# 206        @ABYISINTS  2021-01-25 18:28:01+00:00
# 212        @Lhenryesq  2021-01-26 23:34:12+00:00
# 253  @KUNDANK48787859  2021-01-31 05:55:12+00:00
# 281         @ppatullo  2021-02-02 20:37:06+00:00
# 307      @JuneSummer1  2021-02-03 23:24:27+00:00
# 315        @Instacart  2021-02-03 17:45:52+00:00
# 316        @Instacart  2021-02-03 17:28:50+00:00
# 318        @Instacart  2021-02-03 16:01:32+00:00
# 323        @Instacart  2021-02-03 13:00:48+00:00
# ...

# %%
data.df
# Out:
#               UserName                  Timestamp  \
# 0     @snapchatsupport  2021-01-01 23:36:18+00:00
# 1     @snapchatsupport  2021-01-01 23:35:30+00:00
# 2     @xkombuchaqueenx  2021-01-01 22:00:18+00:00
# 3     @snapchatsupport  2021-01-01 20:55:30+00:00
# 4            @Bruhreeb  2021-01-01 20:53:47+00:00
# ...                ...                        ...
# 2368  @snapchatsupport  2021-03-03 01:51:55+00:00
# 2369  @snapchatsupport  2021-03-03 01:12:43+00:00
# 2370  @snapchatsupport  2021-03-03 00:59:02+00:00
# 2371     @Thegreat_tim  2021-03-03 00:56:04+00:00
# 2372        @AlClemist  2021-03-03 00:23:04+00:00
#
#                                                                                                                                                                                                                                                                                                                   Text  \
# ...
